# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime



# Import the data
df = pd.read_excel('Data\demand_prediction.xls')


df.head()
# Out:
#          date  electricity_sold_total  \
# 0  1995-01-01                   25.64
# 1  1995-02-01                   25.19
# 2  1995-03-01                   30.12
# 3  1995-04-01                   21.60
# 4  1995-05-01                   20.52
#
#    electricity_sold_total First Difference  Seasonal First Difference  \
# 0                                      NaN                        NaN
# 1                                    -0.45                        NaN
# 2                                     4.93                        NaN
# 3                                    -8.52                        NaN
# 4                                    -1.08                        NaN
#
#    forecast
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# Set date column as index
df.set_index('date',inplace=True)

# Remove no longer required columns
df = df.drop(columns=['electricity_sold_total First Difference', 'Seasonal First Difference'])

df.head()
# Out:
#             electricity_sold_total  forecast
# date
# 1995-01-01                   25.64       NaN
# 1995-02-01                   25.19       NaN
# 1995-03-01                   30.12       NaN
# 1995-04-01                   21.60       NaN
# 1995-05-01                   20.52       NaN

# %%
df.plot(xlabel = "",
        ylabel = "Electricity sold (TWh)",
        title = "Predicted vs actual monthly electricity demand in the UK: Historical and Predicted Data",
        figsize=(12, 8))
# Out:
# <AxesSubplot:title={'center':'Predicted vs actual monthly electricity demand in the UK: Historical and Predicted Data'}, ylabel='Electricity sold (TWh)'>

# %%
# Extracting rows from 2019-01-01 - 2021-05-01
sliced_df = df[288:317] 

sliced_df.head()
#sliced_df.tail()
# Out:
#             electricity_sold_total  forecast
# date
# 2019-01-01               26.818707       NaN
# 2019-02-01               23.309735       NaN
# 2019-03-01               24.908721       NaN
# 2019-04-01               22.269014       NaN
# 2019-05-01               21.693864       NaN

# %%
sliced_df.plot(ylabel = "Electricity sold (TWh)", 
               xlabel = "",
               title = "Predicted vs actual monthly electricity demand in the UK",
               figsize=(12, 8))
# Out:
# <AxesSubplot:title={'center':'Predicted vs actual monthly electricity demand in the UK'}, ylabel='Electricity sold (TWh)'>
